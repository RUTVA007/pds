# %%
import pandas as pd

# %%
df = pd.read_csv('Sample_File.csv')

# %%
df.head()
# Out:
#     Name  Age       City
# 0  Rensi   20     Rajkot
# 1   Amit   21  Ahmedabad
# 2   Neha   19      Surat

# %%
df.to_json('Sample_File_json.json')

# %%
df=pd.read_json('Sample_File_json.json')

# %%
df
# Out:
#     Name  Age       City
# 0  Rensi   20     Rajkot
# 1   Amit   21  Ahmedabad
# 2   Neha   19      Surat

# %%
df.to_csv('Sample_File_Excel.csv', index=False)

# %%
df = pd.read_csv('Sample_File_Excel.csv')

# %%
df
# Out:
#     Name  Age       City
# 0  Rensi   20     Rajkot
# 1   Amit   21  Ahmedabad
# 2   Neha   19      Surat

# %%
df.to_csv('SampleFilegzip.gz', compression='gzip', index=False)

# %%
df = pd.read_csv('SampleFilegzip.gz')

# %%
df
# Out:
#     Name  Age       City
# 0  Rensi   20     Rajkot
# 1   Amit   21  Ahmedabad
# 2   Neha   19      Surat
