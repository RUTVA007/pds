# %%
import pandas as pd

# %%
df = pd.read_csv('Houseprices.csv')

# %%
df.head()
# Out:
#     House    Price  Area
# 0  House1  2500000  1200
# 1  House2  3200000  1500
# 2  House3  2800000  1350
# 3  House4  4500000  2000

# %%
print(df.columns)
# Out:
# Index(['House', 'Price', 'Area'], dtype='str')
